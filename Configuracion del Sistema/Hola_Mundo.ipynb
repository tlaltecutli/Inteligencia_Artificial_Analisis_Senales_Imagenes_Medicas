# %% [markdown]
# # Jupyter Notebook para verificar la correcta configuracion del entorno de desarrollo

# %%
print("Hola, Mundo!")
# Out:
# Hola, Mundo!

# %% [markdown]
# ## Revisar las librerias y sus version instaladas en el ambiente virtual

# %%
# !conda list
# Out:
# # packages in environment at C:\ProgramData\anaconda3\envs\env_clase_AI:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2024.10             py312_mkl_0
# aiobotocore               2.12.3          py312haa95532_0
# aiohappyeyeballs          2.4.0           py312haa95532_0
# aiohttp                   3.10.5          py312h827c3e9_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# alabaster                 0.7.16          py312haa95532_0
# altair                    5.0.1           py312haa95532_0
# anaconda-catalogs         0.2.0           py312haa95532_1
# annotated-types           0.6.0           py312haa95532_0
# anyio                     4.2.0           py312haa95532_0
# aom                       3.6.0                hd77b12b_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# archspec                  0.2.3              pyhd3eb1b0_0
# ...

# %% [markdown]
# ## Revisar la version de python instalada en el ambiente virtual

# %%
import sys

print("Python version:")
print(sys.version)

print("\nVersion info:")
print(sys.version_info)
# Out:
# Python version:
# 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]
#
# Version info:
# sys.version_info(major=3, minor=12, micro=3, releaselevel='final', serial=0)

# %% [markdown]
# ## Revisar la version de numpy instalada en el ambiente virtual

# %%
import numpy as np

print("NumPy Version:", np.__version__)
# Out:
# NumPy Version: 1.26.4

# %% [markdown]
# ## Revisar la version de pandas instalada en el ambiente virtual

# %%
import pandas as pd

print("Pandas Version:", pd.__version__)
# Out:
# Pandas Version: 2.2.2
